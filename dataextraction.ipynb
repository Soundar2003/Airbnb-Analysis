# %%
from pymongo import MongoClient
import pandas as pd

# %%
client=MongoClient("mongodb+srv://soundarthangavel2003:soundar@cluster0.eneacqc.mongodb.net/?retryWrites=true&w=majority")

# %%
db=client["sample_airbnb"]
coll=db["listingsAndReviews"]

# %%
coll.count_documents({})
# Out:
# 5555

# %%
summary=[]

# %%
for i in  coll.find({}):
    try:
        data=dict(id=i["_id"],
                  name=i["name"],
                  host_id=i["host"]["host_id"],
                  host_name=i["host"]["host_name"],
                  neighbourhood=i['host']['host_neighbourhood'],
                  longitude=i['address']["location"]['coordinates'][0],
                  latitude=i['address']["location"]['coordinates'][1],
                  property_type=i['property_type'],
                  room_type=i['room_type'],
                  beds=i['beds'],
                  accommodates=i['accommodates'],
                  price=i['price'],
                  availability=i['availability']['availability_365'],
                  minimum_night=i['minimum_nights'],
                  maximum_night=i['maximum_nights'],
                  no_of_reviews=i['number_of_reviews'],
                  rating=i["review_scores"]['review_scores_rating'],
                  host_listings_counts=i['host']['host_listings_count']
                 )
    except:
            pass
    summary.append(data)

# %%
df=pd.DataFrame(summary)

# %%
df
# Out:
#             id                                               name   host_id  \
# 0     10006546                            Ribeira Charming Duplex  51399391
# 1     10006546                            Ribeira Charming Duplex  51399391
# 2      1001265                   Ocean View Waikiki Marina w/prkg   5448114
# 3     10021707                           Private Room in Bushwick  11275734
# 4     10021707                           Private Room in Bushwick  11275734
# ...        ...                                                ...       ...
# 5550   9983221                      Cozy apartment downtown Porto  37776205
# 5551   9983221                      Cozy apartment downtown Porto  37776205
# 5552   9987200       The best suite in Copacabana (total privacy)  51314789
# 5553   9990304     March Madness Special! Aina Nalu Platinum D107  51013381
# 5554   9993190  Just Steps from the Ocean at Premier Platinum ...  51013381
#
# ...

# %%
df.to_csv('my_data.csv')
